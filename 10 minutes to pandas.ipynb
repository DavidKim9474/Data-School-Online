# %% [markdown]
# ### Object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.841618  0.746489  0.888017  0.347075
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643
# 2013-01-04  0.826521  0.245230  0.073436  0.047659
# 2013-01-05  0.733184  0.188135  0.498066  0.103846
# 2013-01-06  0.259179  0.555686  0.321303  0.739699

# %%
df2 = pd.DataFrame({'A': 1., 
                    'B': pd.Timestamp('20130102'), 
                    'C': pd.Series(1, index=list(range(4))), 
                    'D': np.array([3] * 4, dtype='int32'), 
                    'E': pd.Categorical(['test', 'train', 'test', 'train']), 
                    'F': 'foo'})
df2
# Out:
#      A          B  C  D      E    F
# 0  1.0 2013-01-02  1  3   test  foo
# 1  1.0 2013-01-02  1  3  train  foo
# 2  1.0 2013-01-02  1  3   test  foo
# 3  1.0 2013-01-02  1  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C             int64
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ### Viewing data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.841618  0.746489  0.888017  0.347075
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643
# 2013-01-04  0.826521  0.245230  0.073436  0.047659
# 2013-01-05  0.733184  0.188135  0.498066  0.103846

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.826521  0.245230  0.073436  0.047659
# 2013-01-05  0.733184  0.188135  0.498066  0.103846
# 2013-01-06  0.259179  0.555686  0.321303  0.739699

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[0.84161842, 0.74648948, 0.88801718, 0.34707451],
#        [0.56389189, 0.75470522, 0.19386602, 0.1351773 ],
#        [0.85477275, 0.93965217, 0.88376935, 0.64164264],
#        [0.82652141, 0.24523015, 0.07343587, 0.04765929],
#        [0.73318431, 0.18813499, 0.49806621, 0.10384612],
#        [0.25917886, 0.55568647, 0.32130311, 0.7396986 ]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.679861  0.571650  0.476410  0.335850
# std    0.233038  0.301129  0.347018  0.294577
# min    0.259179  0.188135  0.073436  0.047659
# 25%    0.606215  0.322844  0.225725  0.111679
# 50%    0.779853  0.651088  0.409685  0.241126
# 75%    0.837844  0.752651  0.787344  0.568001
# max    0.854773  0.939652  0.888017  0.739699

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.841618    0.563892    0.854773    0.826521    0.733184    0.259179
# B    0.746489    0.754705    0.939652    0.245230    0.188135    0.555686
# C    0.888017    0.193866    0.883769    0.073436    0.498066    0.321303
# D    0.347075    0.135177    0.641643    0.047659    0.103846    0.739699

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-05  0.733184  0.188135  0.498066  0.103846
# 2013-01-04  0.826521  0.245230  0.073436  0.047659
# 2013-01-06  0.259179  0.555686  0.321303  0.739699
# 2013-01-01  0.841618  0.746489  0.888017  0.347075
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643

# %% [markdown]
# ### Selection

# %% [markdown]
# #### Getting

# %%
df['A']
# Out:
# 2013-01-01    0.841618
# 2013-01-02    0.563892
# 2013-01-03    0.854773
# 2013-01-04    0.826521
# 2013-01-05    0.733184
# 2013-01-06    0.259179
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.841618  0.746489  0.888017  0.347075
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643
# 2013-01-04  0.826521  0.245230  0.073436  0.047659

# %% [markdown]
# #### Selection by label

# %%
df.loc[dates[0]]
# Out:
# A    0.841618
# B    0.746489
# C    0.888017
# D    0.347075
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.841618  0.746489
# 2013-01-02  0.563892  0.754705
# 2013-01-03  0.854773  0.939652
# 2013-01-04  0.826521  0.245230
# 2013-01-05  0.733184  0.188135
# 2013-01-06  0.259179  0.555686

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  0.563892  0.754705
# 2013-01-03  0.854773  0.939652
# 2013-01-04  0.826521  0.245230

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    0.563892
# B    0.754705
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# 0.8416184247019315

# %%
df.at[dates[0], 'A']
# Out:
# 0.8416184247019315

# %% [markdown]
# #### Selection by position

# %%
df.iloc[3]
# Out:
# A    0.826521
# B    0.245230
# C    0.073436
# D    0.047659
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.826521  0.245230
# 2013-01-05  0.733184  0.188135

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.563892  0.193866
# 2013-01-03  0.854773  0.883769
# 2013-01-05  0.733184  0.498066

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.746489  0.888017
# 2013-01-02  0.754705  0.193866
# 2013-01-03  0.939652  0.883769
# 2013-01-04  0.245230  0.073436
# 2013-01-05  0.188135  0.498066
# 2013-01-06  0.555686  0.321303

# %%
df.iloc[1, 1]
# Out:
# 0.7547052249046564

# %%
df.iat[1, 1]
# Out:
# 0.7547052249046564

# %% [markdown]
# #### Boolean indexing

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.841618  0.746489  0.888017  0.347075
# 2013-01-02  0.563892  0.754705  0.193866  0.135177
# 2013-01-03  0.854773  0.939652  0.883769  0.641643
# 2013-01-04  0.826521  0.245230  0.073436  0.047659
# 2013-01-05  0.733184  0.188135  0.498066  0.103846
# 2013-01-06  0.259179  0.555686  0.321303  0.739699

# %%
df[df > 0.5]
# Out:
#                    A         B         C         D
# 2013-01-01  0.841618  0.746489  0.888017       NaN
# 2013-01-02  0.563892  0.754705       NaN       NaN
# 2013-01-03  0.854773  0.939652  0.883769  0.641643
# 2013-01-04  0.826521       NaN       NaN       NaN
# 2013-01-05  0.733184       NaN       NaN       NaN
# 2013-01-06       NaN  0.555686       NaN  0.739699

# %%
df2= df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.841618  0.746489  0.888017  0.347075    one
# 2013-01-02  0.563892  0.754705  0.193866  0.135177    one
# 2013-01-03  0.854773  0.939652  0.883769  0.641643    two
# 2013-01-04  0.826521  0.245230  0.073436  0.047659  three
# 2013-01-05  0.733184  0.188135  0.498066  0.103846   four
# 2013-01-06  0.259179  0.555686  0.321303  0.739699  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.854773  0.939652  0.883769  0.641643   two
# 2013-01-05  0.733184  0.188135  0.498066  0.103846  four

# %% [markdown]
# #### Setting

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0], 'A'] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.888017  5  NaN
# 2013-01-02  0.563892  0.754705  0.193866  5  1.0
# 2013-01-03  0.854773  0.939652  0.883769  5  2.0
# 2013-01-04  0.826521  0.245230  0.073436  5  3.0
# 2013-01-05  0.733184  0.188135  0.498066  5  4.0
# 2013-01-06  0.259179  0.555686  0.321303  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0.5] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.888017 -5  NaN
# 2013-01-02 -0.563892 -0.754705  0.193866 -5 -1.0
# 2013-01-03 -0.854773 -0.939652 -0.883769 -5 -2.0
# 2013-01-04 -0.826521  0.245230  0.073436 -5 -3.0
# 2013-01-05 -0.733184  0.188135  0.498066 -5 -4.0
# 2013-01-06  0.259179 -0.555686  0.321303 -5 -5.0

# %% [markdown]
# ### Missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.888017  5  NaN  1.0
# 2013-01-02  0.563892  0.754705  0.193866  5  1.0  1.0
# 2013-01-03  0.854773  0.939652  0.883769  5  2.0  NaN
# 2013-01-04  0.826521  0.245230  0.073436  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.563892  0.754705  0.193866  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.888017  5  5.0  1.0
# 2013-01-02  0.563892  0.754705  0.193866  5  1.0  1.0
# 2013-01-03  0.854773  0.939652  0.883769  5  2.0  5.0
# 2013-01-04  0.826521  0.245230  0.073436  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ### Operations

# %% [markdown]
# #### Stats

# %%
df.mean()
# Out:
# A    0.539592
# B    0.447235
# C    0.476410
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.472004
# 2013-01-02    1.502493
# 2013-01-03    1.935639
# 2013-01-04    1.829037
# 2013-01-05    2.083877
# 2013-01-06    2.227234
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.145227 -0.060348 -0.116231  4.0  1.0
# 2013-01-04 -2.173479 -2.754770 -2.926564  2.0  0.0
# 2013-01-05 -4.266816 -4.811865 -4.501934  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# #### Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.888017   5   NaN
# 2013-01-02  0.563892  0.754705  1.081883  10   1.0
# 2013-01-03  1.418665  1.694357  1.965653  15   3.0
# 2013-01-04  2.245186  1.939588  2.039088  20   6.0
# 2013-01-05  2.978370  2.127723  2.537155  25  10.0
# 2013-01-06  3.237549  2.683409  2.858458  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    0.854773
# B    0.939652
# C    0.814581
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# #### Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    2
# 1    3
# 2    4
# 3    0
# 4    5
# 5    2
# 6    2
# 7    0
# 8    3
# 9    5
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    3
# 5    2
# 3    2
# 0    2
# 4    1
# dtype: int64

# %% [markdown]
# #### String methods

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ### Merge

# %% [markdown]
# #### Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.373123  0.309469 -0.031888 -0.310632
# 1  0.450160  0.668256 -0.386148  0.359232
# 2  1.653829 -0.933639  0.564972 -0.561651
# 3 -0.224388 -0.966053  1.753246 -1.171267
# 4 -0.533327  0.514140  0.092789 -0.465885
# 5  0.281912  0.698381 -0.050798  2.659427
# 6  1.039696 -0.660810 -0.861862  0.834643
# 7  2.415263 -0.462620  0.782101  1.166813
# 8 -0.643981 -0.256341 -0.095802  0.907350
# 9 -0.491945 -0.022628 -0.382039  0.741369

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.373123  0.309469 -0.031888 -0.310632
# 1  0.450160  0.668256 -0.386148  0.359232
# 2  1.653829 -0.933639  0.564972 -0.561651
# 3 -0.224388 -0.966053  1.753246 -1.171267
# 4 -0.533327  0.514140  0.092789 -0.465885
# 5  0.281912  0.698381 -0.050798  2.659427
# 6  1.039696 -0.660810 -0.861862  0.834643
# 7  2.415263 -0.462620  0.782101  1.166813
# 8 -0.643981 -0.256341 -0.095802  0.907350
# 9 -0.491945 -0.022628 -0.382039  0.741369

# %% [markdown]
# #### Join

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ### Grouping

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 
                         'foo', 'bar', 'foo','foo'], 
                   'B': ['one', 'one', 'two', 'three', 
                         'two', 'two', 'one', 'three'],
                   'C': np.random.randn(8), 
                   'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.872516  1.455788
# 1  bar    one  0.412765  0.003167
# 2  foo    two  2.045108  0.618136
# 3  bar  three -0.645189 -0.295277
# 4  foo    two  0.800412  0.877820
# 5  bar    two -1.551238  0.509211
# 6  foo    one -0.055100 -0.392176
# 7  foo  three  0.591581  1.178911

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -1.783663  0.217101
# foo  2.509485  3.738479

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.412765  0.003167
#     three -0.645189 -0.295277
#     two   -1.551238  0.509211
# foo one   -0.927616  1.063612
#     three  0.591581  1.178911
#     two    2.845520  1.495956

# %% [markdown]
# ### Reshaping

# %% [markdown]
# #### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 
                     'foo', 'foo', 'qux', 'qux'], 
                    ['one', 'two', 'one', 'two', 
                     'one', 'two', 'one', 'two']]))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.781625  0.946359
#       two     0.902443  0.016623
# baz   one     0.330123 -0.199257
#       two     0.733389  0.341701

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.781625
#                B    0.946359
#        two     A    0.902443
#                B    0.016623
# baz    one     A    0.330123
#                B   -0.199257
#        two     A    0.733389
#                B    0.341701
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.781625  0.946359
#       two     0.902443  0.016623
# baz   one     0.330123 -0.199257
#       two     0.733389  0.341701

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.781625  0.902443
#       B  0.946359  0.016623
# baz   A  0.330123  0.733389
#       B -0.199257  0.341701

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.781625  0.330123
#        B  0.946359 -0.199257
# two    A  0.902443  0.733389
#        B  0.016623  0.341701

# %% [markdown]
# #### Pivot tables

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two',' three'] * 3, 
                   'B': ['A', 'B', 'C'] * 4, 
                   'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2, 
                   'D': np.random.randn(12), 
                   'E': np.random.randn(12)})
df
# Out:
#          A  B    C         D         E
# 0      one  A  foo -0.702287  0.827848
# 1      one  B  foo  2.283117 -0.226910
# 2      two  C  foo -0.817039  0.579025
# 3    three  A  bar  0.106864  1.248230
# 4      one  B  bar -0.460765 -0.531554
# 5      one  C  bar  0.388166  0.219115
# 6      two  A  foo -0.534061 -0.581387
# 7    three  B  foo  0.172738  1.062116
# 8      one  C  foo -0.940193  0.655472
# 9      one  A  bar  0.451904 -1.033247
# 10     two  B  bar  0.117363 -1.041134
# 11   three  C  bar -0.706696 -0.349772

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C              bar       foo
# A      B
#  three A  0.106864       NaN
#        B       NaN  0.172738
#        C -0.706696       NaN
# one    A  0.451904 -0.702287
#        B -0.460765  2.283117
#        C  0.388166 -0.940193
# two    A       NaN -0.534061
#        B  0.117363       NaN
#        C       NaN -0.817039

# %% [markdown]
# ### Time series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    24028
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.478324
# 2012-03-07    0.253797
# 2012-03-08   -0.977603
# 2012-03-09   -1.148911
# 2012-03-10    0.373150
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.478324
# 2012-03-07 00:00:00+00:00    0.253797
# 2012-03-08 00:00:00+00:00   -0.977603
# 2012-03-09 00:00:00+00:00   -1.148911
# 2012-03-10 00:00:00+00:00    0.373150
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.478324
# 2012-03-06 19:00:00-05:00    0.253797
# 2012-03-07 19:00:00-05:00   -0.977603
# 2012-03-08 19:00:00-05:00   -1.148911
# 2012-03-09 19:00:00-05:00    0.373150
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    1.244619
# 2012-02-29    1.046580
# 2012-03-31    1.751971
# 2012-04-30   -2.062762
# 2012-05-31   -0.966502
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    1.244619
# 2012-02    1.046580
# 2012-03    1.751971
# 2012-04   -2.062762
# 2012-05   -0.966502
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    1.244619
# 2012-02-01    1.046580
# 2012-03-01    1.751971
# 2012-04-01   -2.062762
# 2012-05-01   -0.966502
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1999Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1999-03-01 09:00    0.863938
# 1999-06-01 09:00   -1.897257
# 1999-09-01 09:00    0.856544
# 1999-12-01 09:00    0.310894
# 2000-03-01 09:00    1.093745
# Freq: H, dtype: float64

# %% [markdown]
# ### Categoricals

# %%
df = pd.DataFrame({'id': [1, 2, 3, 4, 5, 6], 
                   'raw_grade': ['a', 'b', 'b', 'a', 'a', 'e']})
df['grade'] = df['raw_grade'].astype('category')
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df['grade'].cat.categories = ['very good', 'good', 'very bad']

# %%
df['grade'] = df['grade'].cat.set_categories(['very bad', 'bad', 'medium', 
                                              'good', 'very good'])
df['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by='grade')
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby('grade').size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ### Plotting

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000), 
               index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, 
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best')

# %% [markdown]
# ### Getting data in/out

# %% [markdown]
# #### CSV

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A         B         C          D
# 0    2000-01-01   0.506389 -0.278856  0.649757   0.702165
# 1    2000-01-02   2.033355  0.251416  0.568575  -0.063984
# 2    2000-01-03   0.885595 -1.681196  0.122665   0.263110
# 3    2000-01-04  -0.370044  0.086005 -0.253862   1.100240
# 4    2000-01-05  -1.027765  0.087752  1.501452  -0.950586
# ..          ...        ...       ...       ...        ...
# 995  2002-09-22 -27.734766 -3.838712 -4.582367 -12.373735
# 996  2002-09-23 -27.872568 -4.479525 -3.343238 -13.367043
# 997  2002-09-24 -28.576177 -5.770654 -3.464212 -13.283673
# 998  2002-09-25 -28.938686 -5.766883 -4.374437 -12.244643
# 999  2002-09-26 -27.175764 -5.781912 -4.091738 -11.675252
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### HDF5

# %%
df.to_hdf('foo.h5', 'df')

# %%
pd.read_hdf('foo.h5', 'df')
# Out:
#                     A         B         C          D
# 2000-01-01   0.506389 -0.278856  0.649757   0.702165
# 2000-01-02   2.033355  0.251416  0.568575  -0.063984
# 2000-01-03   0.885595 -1.681196  0.122665   0.263110
# 2000-01-04  -0.370044  0.086005 -0.253862   1.100240
# 2000-01-05  -1.027765  0.087752  1.501452  -0.950586
# ...               ...       ...       ...        ...
# 2002-09-22 -27.734766 -3.838712 -4.582367 -12.373735
# 2002-09-23 -27.872568 -4.479525 -3.343238 -13.367043
# 2002-09-24 -28.576177 -5.770654 -3.464212 -13.283673
# 2002-09-25 -28.938686 -5.766883 -4.374437 -12.244643
# 2002-09-26 -27.175764 -5.781912 -4.091738 -11.675252
#
# [1000 rows x 4 columns]

# %% [markdown]
# #### Excel

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0          A         B         C          D
# 0   2000-01-01   0.506389 -0.278856  0.649757   0.702165
# 1   2000-01-02   2.033355  0.251416  0.568575  -0.063984
# 2   2000-01-03   0.885595 -1.681196  0.122665   0.263110
# 3   2000-01-04  -0.370044  0.086005 -0.253862   1.100240
# 4   2000-01-05  -1.027765  0.087752  1.501452  -0.950586
# ..         ...        ...       ...       ...        ...
# 995 2002-09-22 -27.734766 -3.838712 -4.582367 -12.373735
# 996 2002-09-23 -27.872568 -4.479525 -3.343238 -13.367043
# 997 2002-09-24 -28.576177 -5.770654 -3.464212 -13.283673
# 998 2002-09-25 -28.938686 -5.766883 -4.374437 -12.244643
# 999 2002-09-26 -27.175764 -5.781912 -4.091738 -11.675252
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### Gotchas

# %%
if pd.Series([False, True, False]):
    print('I was true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-e23b6e887fca> in <module>
# ----> 1 if pd.Series([False, True, False]):
#       2     print('I was true')
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
