# %%
import geopandas as gpd

seoul_file = './TC_SPBE17_2015_W_SHP/TC_SPBE17_2015_W.shp'
seoul = gpd.read_file(seoul_file, encoding='euckr')
seoul.tail()
# Out:
#        EMD_CD EMD_NM              EMD_ENG_NM  ESRI_PK  SHAPE_AREA  SHAPE_LEN  \
# 462  11680104    청담동          Cheongdam-dong      465    0.000238   0.070422
# 463  11290116  동선동1가  Dongseon-dong 1(il)-ga      466    0.000008   0.012183
# 464  11380110    증산동           Jeungsan-dong      437    0.000083   0.045973
# 465  11380105    구산동              Gusan-dong      438    0.000142   0.053630
# 466  11380108    역촌동           Yeokchon-dong      446    0.000118   0.058186
#
#                                               geometry
# 462  POLYGON ((127.05259 37.53031, 127.05285 37.530...
# 463  POLYGON ((127.01699 37.59045, 127.01697 37.590...
# 464  POLYGON ((126.91076 37.58927, 126.91078 37.589...
# 465  POLYGON ((126.90601 37.61893, 126.90608 37.618...
# 466  POLYGON ((126.91753 37.61110, 126.91756 37.611...

# %%
market_file = './contents.csv'
market = pd.read_csv(market_file, encoding='euckr')
market.tail(3)
# Out:
#     콘텐츠 ID\n(필수 입력) 사용유무\n(필수입력) 콘텐츠명\n(필수 입력) 서브카테고리 명\n(선택 입력)  시군\n(선택입력)  \
# 346  Sijang_ddm_004            Y          동서시장              일반시장         NaN
# 347  Sijang_ddm_003            Y          경동시장              일반시장         NaN
# 348  Sijang_ddm_001            Y          용두시장              일반시장         NaN
#
#     구명\n(선택입력) 새주소[도로명 주소]\n(조건부 선택 입력)            지번주소  키워드 다국어\n(필수 입력)  \
# 346       동대문구                왕산로33길 13    동대문구 제기동 650  NaN          KOR
# 347       동대문구                  왕산로 147   동대문구 제기동 1018  NaN          KOR
# 348       동대문구                 한빛로 62-1  동대문구 용두동 231-5  NaN          KOR
#
#      ...  상세 제목16\n(선택 입력)  상세 내용16\n(선택 입력)  상세 제목17\n(선택 입력)  \
# 346  ...               NaN               NaN               NaN
# 347  ...               NaN               NaN               NaN
# 348  ...               NaN               NaN               NaN
#
#     상세 내용17\n(선택 입력) 상세 제목18\n(선택 입력)  상세 내용18\n(선택 입력) 상세 제목19\n(선택 입력)  \
# ...

# %%
address = list('서울 특별시 ' + market['지번주소'].sample(50))
address[:3]
# Out:
# ['서울 특별시 중구 남대문로4가 20-60', '서울 특별시 양천구 목동 526', '서울 특별시 성북구 동소문동5가 59-1']

# %%
location = gpd.tools.geocode(address, provider='googlev3', api_key='AIzaSyDIOkZNFSSKg7EhozLr_Kaic6GrvIyCzFk')
location.tail()
# Out:
# C:\Anaconda\lib\site-packages\geopandas\array.py:689: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 0]),  # minx
# C:\Anaconda\lib\site-packages\geopandas\array.py:690: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 1]),  # miny
# C:\Anaconda\lib\site-packages\geopandas\array.py:691: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 2]),  # maxx
# C:\Anaconda\lib\site-packages\geopandas\array.py:692: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 3]),  # maxy
# C:\Anaconda\lib\site-packages\geopandas\array.py:689: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 0]),  # minx
# C:\Anaconda\lib\site-packages\geopandas\array.py:690: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 1]),  # miny
# C:\Anaconda\lib\site-packages\geopandas\array.py:691: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 2]),  # maxx
# ...

# %%
ax = seoul.plot(figsize=(11, 11), color='w', edgecolor='k')
ax.set_axis_off()
ax.set_title('서울시 내 전통시장들의 위치')
location.plot(ax=ax, color='r')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\geopandas\array.py:689: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 0]),  # minx
# C:\Anaconda\lib\site-packages\geopandas\array.py:690: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 1]),  # miny
# C:\Anaconda\lib\site-packages\geopandas\array.py:691: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 2]),  # maxx
# C:\Anaconda\lib\site-packages\geopandas\array.py:692: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 3]),  # maxy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d3805c8562c8> in <module>
#       2 ax.set_axis_off()
#       3 ax.set_title('서울시 내 전통시장들의 위치')
# ----> 4 location.plot(ax=ax, color='r')
#       5 plt.show()
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# ...
