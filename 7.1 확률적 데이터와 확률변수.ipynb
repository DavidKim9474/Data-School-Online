# %% [markdown]
# #### 분포

# %%
np.random.seed(0)
x = np.random.normal(size=21)
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574,
#        -2.55298982])

# %%
bins = np.linspace(-4, 4, 17)
sns.distplot(x, rug=True, kde=False, bins=bins)
plt.title("히스토그램으로 나타낸 데이터 분포")
plt.xlabel("x")
plt.show()

# %% [markdown]
# #### 파이썬을 사용한 대푯값 계산

# %%
print("표본평균 = {}, 표본중앙값 = {}".format(np.mean(x), np.median(x)))
# Out:
# 표본평균 = 0.4206524782418389, 표본중앙값 = 0.4001572083672233

# %%
ns, _ = np.histogram(x, bins=bins)
m_bin = np.argmax(ns)
print("최빈구간 = {}~{}".format(bins[m_bin], bins[m_bin + 1]))
# Out:
# 최빈구간 = 0.0~0.5

# %% [markdown]
# #### Ex. 7.1.1

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
sy = pd.Series(iris.target, dtype='category')
sy = sy.cat.rename_categories(iris.target_names)
df['species'] = sy

# %%
x = df['petal length (cm)'].values
x
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
sns.distplot(x)

# %%
x = df[df.species == 'setosa']['petal length (cm)']
sns.distplot(x)

# %% [markdown]
# #### 대칭분포

# %%
np.random.seed(1)
x = np.random.normal(size=1000)
x = np.hstack([x, 5 * np.ones(50)])
bins = np.linspace(-6, 6, 12 * 4 + 1)
ns, _ = np.histogram(x, bins=bins)

sample_mean = np.mean(x)
sample_median = np.median(x)
mode_index = np.argmax(ns)
sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])

sns.distplot(x, bins=bins)
plt.axvline(sample_mean, c='k', ls=":", label='표본평균')
plt.axvline(sample_median, c='k', ls="--", label='표본중앙값')
plt.axvline(sample_mode, c='k', ls="-", label='표본최빈값')
plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# #### Ex. 7.1.2

# %%
x = df[df.species == 'virginica']['petal length (cm)']

bins = np.linspace(0, 10, 10)
ns, _ = np.histogram(x, bins=bins)

sample_mean = np.mean(x)
sample_median = np.median(x)
mode_index = np.argmax(ns)
sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])

sns.distplot(x, bins=bins)
plt.axvline(sample_mean, c='k', ls=":", label='표본평균')
plt.axvline(sample_median, c='k', ls="--", label='표본중앙값')
plt.axvline(sample_mode, c='k', ls="-", label='표본최빈값')
plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
plt.xlabel("x")
plt.legend()
plt.show()

print("표본평균 = {}, 표본중앙값 = {}".format(sample_mean, sample_median))
print("표본최빈값 = {}".format(sample_mode))
# Out:
# 표본평균 = 5.552, 표본중앙값 = 5.55
# 표본최빈값 = 5.0

# %%
bins = np.linspace(0, 10, 50)
ns, _ = np.histogram(x, bins=bins)

sample_mean = np.mean(x)
sample_median = np.median(x)
mode_index = np.argmax(ns)
sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])

sns.distplot(x, bins=bins)
plt.axvline(sample_mean, c='k', ls=":", label='표본평균')
plt.axvline(sample_median, c='k', ls="--", label='표본중앙값')
plt.axvline(sample_mode, c='k', ls="-", label='표본최빈값')
plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
plt.xlabel("x")
plt.legend()
plt.show()

print("표본평균 = {}, 표본중앙값 = {}".format(sample_mean, sample_median))
print("표본최빈값 = {}".format(sample_mode))
# Out:
# 표본평균 = 5.552, 표본중앙값 = 5.55
# 표본최빈값 = 5.0

# %%
bins = np.linspace(0, 10, 100)
ns, _ = np.histogram(x, bins=bins)

sample_mean = np.mean(x)
sample_median = np.median(x)
mode_index = np.argmax(ns)
sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])

sns.distplot(x, bins=bins)
plt.axvline(sample_mean, c='k', ls=":", label='표본평균')
plt.axvline(sample_median, c='k', ls="--", label='표본중앙값')
plt.axvline(sample_mode, c='k', ls="-", label='표본최빈값')
plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
plt.xlabel("x")
plt.legend()
plt.show()

print("표본평균 = {}, 표본중앙값 = {}".format(sample_mean, sample_median))
print("표본최빈값 = {}".format(sample_mode))
# Out:
# 표본평균 = 5.552, 표본중앙값 = 5.55
# 표본최빈값 = 5.1010101010101

# %% [markdown]
# #### 파이썬을 사용한 표본분산 및 표본표준편차의 계산

# %%
sp.random.seed()
x = sp.stats.norm(0, 2).rvs(1000)    # 평균=0, 표준편차=2인 정규분포 데이터 생성

# %%
np.var(x), np.std(x)    # 편향 표본분산, 표본표준편차
# Out:
# (4.038157540653332, 2.0095167430636978)

# %%
np.var(x, ddof=1), np.std(x, ddof=1)    # 비편향 표본분산, 표본표분편차
# Out:
# (4.042199740393726, 2.0105222556325324)

# %% [markdown]
# #### Ex. 7.1.3

# %%
import pandas_datareader.data as web

df = web.DataReader("DJCA", data_source='fred').dropna()['DJCA']
r = np.log(df / df.shift(1)).dropna().values

# %%
df, df.shape
# Out:
# (DATE
#  2015-10-01    5808.61
#  2015-10-02    5869.27
#  2015-10-05    5981.21
#  2015-10-06    5957.99
#  2015-10-07    6002.17
#                 ...
#  2020-09-21    9009.48
#  2020-09-22    9064.70
#  2020-09-23    8912.40
#  2020-09-24    8946.61
#  2020-09-25    9069.85
#  Name: DJCA, Length: 1254, dtype: float64,
#  (1254,))

# %%
r, r.shape
# Out:
# (array([ 0.01038897,  0.01889262, -0.00388971, ..., -0.01694418,
#          0.00383112,  0.01368104]),
#  (1253,))

# %%
np.mean(r), np.var(r), np.std(r)
# Out:
# (0.00035563800989393953, 0.00015221988035768222, 0.012337742109384611)

# %%
annual_volatility = np.std(r) * 16 * 100
annual_volatility
# Out:
# 19.740387375015377

# %% [markdown]
# #### 표본비대칭도, 표본첨도

# %%
sp.stats.skew(x), sp.stats.kurtosis(x)
# Out:
# (0.0027059605034511045, -0.05328382810227561)

# %% [markdown]
# #### 표본모멘트

# %%
sp.stats.moment(x, 1), sp.stats.moment(x, 2), sp.stats.moment(x, 3), sp.stats.moment(x, 4)
# Out:
# (0.0, 4.038157540653332, 0.021958179977198143, 48.05126469993158)

# %% [markdown]
# #### Ex. 7.1.4

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]
